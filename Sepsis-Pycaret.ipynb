# %% [markdown]
# This is the code of the experiment we just need to change the dataset that we are testing on code for resampling is also provide

# %% [markdown]
# # Installing PyCaret

# %% [markdown]
# # Data Source
# https://archive.ics.uci.edu/ml/datasets/Heart+failure+clinical+records
# https://www.kaggle.com/datasets/andrewmvd/heart-failure-clinical-data

# %% [markdown]
# # Upload dataset from user-system

# %% [markdown]
# # Read dataset

# %%
import pandas as pd
dataset = pd.read_csv('datasets\primary_upscaled.csv') # here file name is the name of file that is read in above

# %%
#dataset = dataset.dropna(axis=0)

# %%
dataset.shape
# Out:
# (204198, 4)

# %%
dataset.head()
# Out:
#    age_years  sex_0male_1female  episode_number  target
# 0         89                  0               2       0
# 1         86                  1               1       1
# 2         56                  1               1       1
# 3         78                  1               1       1
# 4         57                  0               1       0

# %% [markdown]
# # Import all classification methods

# %%
from pycaret.classification import *

# %% [markdown]
# # Setup function initializes the training environment

# %%
s = setup(data=dataset, target='target',train_size = 0.80)
#s = setup(data=dataset, target='hospital_outcome_1alive_0dead',class_imbalance,remove_outliers = True, train_size = 0.80)
# Out:
# <style type="text/css">
# #T_f46a0_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f46a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f46a0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f46a0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f46a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f46a0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f46a0_row0_col1" class="data row0 col1" >6779</td>
#     </tr>
#     <tr>
#       <th id="T_f46a0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f46a0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f46a0_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_f46a0_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# # Run and Compare all ML models

# %%
rf_classifier = create_model('rf')
# Out:
# <style type="text/css">
# #T_17ac6_row10_col0, #T_17ac6_row10_col1, #T_17ac6_row10_col2, #T_17ac6_row10_col3, #T_17ac6_row10_col4, #T_17ac6_row10_col5, #T_17ac6_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_17ac6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17ac6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_17ac6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_17ac6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_17ac6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_17ac6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_17ac6_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_17ac6_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
tuned_rf = tune_model(rf_classifier, custom_grid={'n_estimators': [100, 200, 300], 'max_depth': [None, 10, 20, 30]})
# Out:
# <style type="text/css">
# #T_1f6f0_row10_col0, #T_1f6f0_row10_col1, #T_1f6f0_row10_col2, #T_1f6f0_row10_col3, #T_1f6f0_row10_col4, #T_1f6f0_row10_col5, #T_1f6f0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1f6f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f6f0_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1f6f0_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1f6f0_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1f6f0_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1f6f0_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1f6f0_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_1f6f0_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
cm = compare_models()
# Out:
# <style type="text/css">
# #T_a6f4f th {
#   text-align: left;
# }
# ...

# %%
 evaluate_model(cm)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
m = create_model('dt')
print (m)
# Out:
# <style type="text/css">
# #T_5b8cd_row10_col0, #T_5b8cd_row10_col1, #T_5b8cd_row10_col2, #T_5b8cd_row10_col3, #T_5b8cd_row10_col4, #T_5b8cd_row10_col5, #T_5b8cd_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5b8cd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b8cd_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5b8cd_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5b8cd_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5b8cd_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5b8cd_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5b8cd_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5b8cd_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
 evaluate_model(m)

# %%
predict_model(m);
# Out:
# <style type="text/css">
# </style>
# <table id="T_e96af" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e96af_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e96af_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e96af_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e96af_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e96af_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e96af_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e96af_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e96af_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e96af_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# https://www.geeksforgeeks.org/quadratic-discriminant-analysis/

# %% [markdown]
# data preprocessing
# drop cols, imputer(num-mean,categorial-mode), clean col names, split train-test data
# (Trainset -70%
# test-30%), ML Algorithm
